# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = llm.invoke("What is the capital of India?")
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain_openai import ChatOpenAI
from openai import RateLimitError
import time
from typing import Any

print("the token limit is expired need to be recharge")


# def invoke_with_retry(llm: Any, prompt: str, max_retries: int = 3, base_delay: float = 1.0):
#     """Invoke an LLM with exponential-backoff retry for rate-limit errors."""
#     for attempt in range(max_retries):
#         try:
#             return llm.invoke(prompt)
#         except RateLimitError as exc:
#             if attempt == max_retries - 1:
#                 raise RuntimeError(
#                     "OpenAI rate limit/billing issue. Check usage/billing in your OpenAI project, "
#                     "or wait and retry."
#                 ) from exc
#             time.sleep(base_delay * (2 ** attempt))


# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# response = invoke_with_retry(llm, "What is the capital of India?")
# print(response.content)
# Out:
# the token limit is expired need to be recharge

# %% [markdown]
# ## STATIC PROMPT

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

prompts = [
    ("system", "You are a python developer"),
    ("user", "how to sort the array?"),
]

response = llm.invoke(prompts)
print(response.content)
